# %%
# %load_ext tensorboard
# %tensorboard --logdir ./logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6008 (pid 20764), started 0:44:34 ago. (Use '!kill 20764' to kill it.)
#       <iframe id="tensorboard-frame-b96c8a6972ec161e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b96c8a6972ec161e");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
